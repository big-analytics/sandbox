# %%
import googlemaps
import json
import pandas
import re
import sys
from datetime import datetime

gmaps = googlemaps.Client(key='AIzaSyBfp09visaSvIFh8hFt1yzI-wAhgs4v7uU')

df = pandas.read_csv('/Users/gratiel/Documents/work/house_location/sales.txt')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22203 entries, 0 to 22202
# Data columns (total 12 columns):
# ID             22203 non-null int64
# POSTAL_CODE    22203 non-null int64
# BEDROOMS       22203 non-null int64
# LIVING_AREA    20815 non-null float64
# LAND           9617 non-null float64
# PRICE          22203 non-null int64
# POSTED         22203 non-null object
# VIEWS          16736 non-null float64
# SAVES          16736 non-null float64
# TYPE           22203 non-null object
# LOCATION       22116 non-null object
# COMMUNE        21069 non-null object
# dtypes: float64(4), int64(4), object(4)
# memory usage: 2.0+ MB

# %%
test_df = df[(df['POSTAL_CODE']==1800) & (df['BEDROOMS'].isin([3,4,5]))].head(50)

test_df["G_LOCATION"] = ''
test_df["G_LAT"] = ''
test_df["G_LNG"] = ''

#test_df.LOCATION
# Out:
# Hello

# %%
num_location = 0
for idx, row in test_df.iterrows():
    sys.stdout.write(row)
    #print "before="+row["LOCATION"]
    geocode_result = json.dumps(gmaps.geocode(row["LOCATION"]), sort_keys=True, indent=4)
    #print geocode_result
    
    #print "==================="
    
    if geocode_result.count('\n') == 0:
        formatted_address = ''
        lat = ''
        lng = ''
    else:
        parsed_result = geocode_result.split("{", 1)[1:]
        parsed_result = "{"+''.join(parsed_result)
        parsed_result = parsed_result.split("\n")[:-1]
        parsed_result = ''.join(parsed_result)
        
        #print type(parsed_result)
        #print parsed_result
        
        parsed_result = json.loads(parsed_result)
        #print parsed_result
        formatted_address = parsed_result['formatted_address']
        lat = parsed_result['geometry']['location']['lat']
        lng = parsed_result['geometry']['location']['lng']
    
    #print "after="+formatted_address
    #print lat
    #print lng
    
    test_df.G_LOCATION[idx] = formatted_address
    test_df.G_LAT[idx] = lat
    test_df.G_LNG[idx] = lng
    
#test_df
# Out:
# ID                                                       7155361
# POSTAL_CODE                                                 1800
# BEDROOMS                                                       3
# LIVING_AREA                                                  220
# LAND                                                         NaN
# PRICE                                                     395000
# POSTED                                                  9/9/2017
# VIEWS                                                        NaN
# SAVES                                                        NaN
# TYPE                                                   Apartment
# LOCATION       Hondenbergstraat    bus    in  DEELGEMEENTE  H...
# COMMUNE                                                Vilvoorde
# G_LOCATION
# G_LAT
# G_LNG
# Name: 17155, dtype: object
# /Users/gratiel/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gratiel/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/gratiel/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ID                                                      7154599
# POSTAL_CODE                                                1800
# BEDROOMS                                                      3
# LIVING_AREA                                                 NaN
# LAND                                                        100
# PRICE                                                    275000
# POSTED                                                 9/8/2017
# VIEWS                                                       NaN
# SAVES                                                       NaN
# TYPE                                                      House
# LOCATION          Strombeekse  Steenweg  250 1800    Vilvoorde
# COMMUNE                                               Vilvoorde
# G_LOCATION     Strombeeksesteenweg 250, 1800 Vilvoorde, Belgium
# G_LAT                                                   50.9087
# G_LNG                                                   4.36596
# Name: 17156, dtype: object
# ID                        7153094
# POSTAL_CODE                  1800
# BEDROOMS                        3
# LIVING_AREA                   160
# LAND                          NaN
# PRICE                      137000
# POSTED                   9/8/2017
# VIEWS                         NaN
# SAVES                         NaN
# TYPE                        House
# LOCATION       1800    Vilvoorde
# COMMUNE                 Vilvoorde
# G_LOCATION          1800, Belgium
# G_LAT                     50.9377
# G_LNG                     4.46053
# Name: 17157, dtype: object
# ID                        7152365
# POSTAL_CODE                  1800
# BEDROOMS                        4
# LIVING_AREA                   185
# LAND                          NaN
# PRICE                      295000
# POSTED                   9/7/2017
# VIEWS                         NaN
# SAVES                         NaN
# TYPE                        House
# LOCATION       1800    Vilvoorde
# COMMUNE                 Vilvoorde
# G_LOCATION          1800, Belgium
# G_LAT                     50.9377
# G_LNG                     4.46053
# Name: 17158, dtype: object
# ID                                                 7151794
# POSTAL_CODE                                           1800
# BEDROOMS                                                 3
# LIVING_AREA                                            125
# LAND                                                    55
# PRICE                                               199500
# POSTED                                            9/7/2017
# VIEWS                                                  NaN
# SAVES                                                  NaN
# TYPE                                                 House
# LOCATION            Spuymolenstraat  94 1800    Vilvoorde
# COMMUNE                                          Vilvoorde
# G_LOCATION     Spuymolenstraat 94, 1800 Vilvoorde, Belgium
# G_LAT                                              50.9305
# G_LNG                                              4.41887
# Name: 17159, dtype: object
# ID                                               7151267
# POSTAL_CODE                                         1800
# BEDROOMS                                               4
# LIVING_AREA                                          NaN
# LAND                                                 238
# PRICE                                             375000
# POSTED                                          9/7/2017
# VIEWS                                                NaN
# SAVES                                                NaN
# TYPE                                               House
# LOCATION            Schaarbeeklei  23 1800    Vilvoorde
# COMMUNE                                        Vilvoorde
# G_LOCATION     Schaarbeeklei 23, 1800 Vilvoorde, Belgium
# G_LAT                                            50.9254
# G_LNG                                            4.42626
# Name: 17160, dtype: object
# ID                                               7150251
# POSTAL_CODE                                         1800
# BEDROOMS                                               4
# LIVING_AREA                                          228
# LAND                                                 145
# PRICE                                             364000
# POSTED                                          9/6/2017
# VIEWS                                                NaN
# SAVES                                                NaN
# TYPE                                               House
# LOCATION           Permekestraat  11 1800     Vilvoorde
# COMMUNE                                        Vilvoorde
# G_LOCATION     Permekestraat 11, 1800 Vilvoorde, Belgium
# G_LAT                                            50.9232
# G_LNG                                            4.40447
# Name: 17161, dtype: object
# ID                                                7149530
# POSTAL_CODE                                          1800
# BEDROOMS                                                3
# LIVING_AREA                                           160
# LAND                                                  125
# PRICE                                              315000
# POSTED                                           9/6/2017
# VIEWS                                                 NaN
# SAVES                                                 NaN
# TYPE                                                House
# LOCATION              Mutsaertstraat13 1800    Koningslo
# COMMUNE                                         Vilvoorde
# G_LOCATION     Mutsaertstraat 13, 1800 Vilvoorde, Belgium
# G_LAT                                             50.9016
# G_LNG                                             4.36341
# Name: 17162, dtype: object
# ID                                             7148370
# POSTAL_CODE                                       1800
# BEDROOMS                                             3
# LIVING_AREA                                        100
# LAND                                               120
# PRICE                                           245000
# POSTED                                        9/5/2017
# VIEWS                                              114
# SAVES                                                0
# TYPE                                             House
# LOCATION            Hellestraat  13 1800    Vilvoorde
# COMMUNE                                      Vilvoorde
# G_LOCATION     Hellestraat 13, 1800 Vilvoorde, Belgium
# G_LAT                                          50.9329
# G_LNG                                          4.42255
# Name: 17163, dtype: object
# ID                        7146702
# POSTAL_CODE                  1800
# BEDROOMS                        3
# LIVING_AREA                   160
# LAND                          876
# PRICE                      352744
# POSTED                   9/4/2017
# VIEWS                         193
# SAVES                           1
# TYPE                        House
# LOCATION       1800    Vilvoorde
# COMMUNE                 Vilvoorde
# G_LOCATION          1800, Belgium
# G_LAT                     50.9377
# G_LNG                     4.46053
# Name: 17165, dtype: object
# ID                                                   7146699
# POSTAL_CODE                                             1800
# BEDROOMS                                                   3
# LIVING_AREA                                              206
# LAND                                                     326
# PRICE                                                 339000
# POSTED                                              9/4/2017
# VIEWS                                                    206
# SAVES                                                      1
# TYPE                                                   House
# LOCATION            Houtemsesteenweg  326 1800    Vilvoorde
# COMMUNE                                            Vilvoorde
# G_LOCATION     Houtemsesteenweg 326, 1800 Vilvoorde, Belgium
# G_LAT                                                50.9411
# G_LNG                                                 4.4583
# Name: 17166, dtype: object
# ID                        7145559
# POSTAL_CODE                  1800
# BEDROOMS                        3
# LIVING_AREA                   160
# LAND                          876
# PRICE                      352744
# POSTED                   9/4/2017
# VIEWS                         196
# SAVES                           2
# TYPE                        House
# LOCATION       1800    Vilvoorde
# COMMUNE                 Vilvoorde
# G_LOCATION          1800, Belgium
# G_LAT                     50.9377
# G_LNG                     4.46053
# Name: 17168, dtype: object
# ID                                              7145428
# POSTAL_CODE                                        1800
# BEDROOMS                                              3
# LIVING_AREA                                         NaN
# LAND                                                196
# PRICE                                             97000
# POSTED                                         9/4/2017
# VIEWS                                               334
# SAVES                                                 6
# TYPE                                              House
# LOCATION             Schriekwegel  10 1800    Vilvorde
# COMMUNE                                       Vilvoorde
# G_LOCATION     Schriekwegel 10, 1800 Vilvoorde, Belgium
# G_LAT                                           50.9457
# G_LNG                                           4.46821
# Name: 17169, dtype: object
# ID                                           7145419
# POSTAL_CODE                                     1800
# BEDROOMS                                           3
# LIVING_AREA                                      NaN
# LAND                                             175
# PRICE                                          93000
# POSTED                                      9/4/2017
# VIEWS                                            502
# SAVES                                             10
# TYPE                                           House
# LOCATION            Schriekwegel   1800    Vilvorde
# COMMUNE                                    Vilvoorde
# G_LOCATION     Schriekwegel, 1800 Vilvoorde, Belgium
# G_LAT                                        50.9455
# G_LNG                                        4.46841
# Name: 17170, dtype: object
# ID                        7144071
# POSTAL_CODE                  1800
# BEDROOMS                        5
# LIVING_AREA                   379
# LAND                         3527
# PRICE                     1395000
# POSTED                   9/2/2017
# VIEWS                         345
# SAVES                           3
# TYPE                     Building
# LOCATION       1800    Vilvoorde
# COMMUNE                 Vilvoorde
# G_LOCATION          1800, Belgium
# G_LAT                     50.9377
# G_LNG                     4.46053
# Name: 17171, dtype: object
# ID                                                 7140201
# POSTAL_CODE                                           1800
# BEDROOMS                                                 3
# LIVING_AREA                                            NaN
# LAND                                                   180
# PRICE                                                    0
# POSTED                                           8/31/2017
# VIEWS                                                  NaN
# SAVES                                                  NaN
# TYPE                                                 House
# LOCATION             Vlierkensstraat  35 1800    Vilvorde
# COMMUNE                                          Vilvoorde
# G_LOCATION     Vlierkensstraat 35, 1800 Vilvoorde, Belgium
# G_LAT                                              50.9244
# G_LNG                                              4.41163
# Name: 17172, dtype: object
# ID                         7139892
# POSTAL_CODE                   1800
# BEDROOMS                         3
# LIVING_AREA                    NaN
# LAND                           NaN
# PRICE                       720000
# POSTED                   8/31/2017
# VIEWS                          NaN
# SAVES                          NaN
# TYPE                         House
# LOCATION       1800     Vilvoorde
# COMMUNE                  Vilvoorde
# G_LOCATION           1800, Belgium
# G_LAT                      50.9377
# G_LNG                      4.46053
# Name: 17173, dtype: object
# ID                                                    7137355
# POSTAL_CODE                                              1800
# BEDROOMS                                                    3
# LIVING_AREA                                               150
# LAND                                                      257
# PRICE                                                  349000
# POSTED                                              8/30/2017
# VIEWS                                                     NaN
# SAVES                                                     NaN
# TYPE                                                    House
# LOCATION       Amazonenlaan  41 1800    Vilvoorde  Koningslo
# COMMUNE                                             Vilvoorde
# G_LOCATION           Amazonenlaan 41, 1800 Vilvoorde, Belgium
# G_LAT                                                 50.9057
# G_LNG                                                 4.36495
# Name: 17176, dtype: object
# ID                                                   7136771
# POSTAL_CODE                                             1800
# BEDROOMS                                                   4
# LIVING_AREA                                              140
# LAND                                                     242
# PRICE                                                 199000
# POSTED                                             8/29/2017
# VIEWS                                                    110
# SAVES                                                      3
# TYPE                                                   House
# LOCATION               Aarschotsestraat  122 1800    Peutie
# COMMUNE                                            Vilvoorde
# G_LOCATION     Aarschotsestraat 122, 1800 Vilvoorde, Belgium
# G_LAT                                                50.9262
# G_LNG                                                4.45776
# Name: 17177, dtype: object
# ID                                                      7135808
# POSTAL_CODE                                                1800
# BEDROOMS                                                      3
# LIVING_AREA                                                 NaN
# LAND                                                        194
# PRICE                                                    309000
# POSTED                                                8/29/2017
# VIEWS                                                       427
# SAVES                                                        11
# TYPE                                                      House
# LOCATION       Weikantstraat  18A 1800    Vilvoorde  Koningslo
# COMMUNE                                               Vilvoorde
# G_LOCATION            Weikantstraat 18, 1800 Vilvoorde, Belgium
# G_LAT                                                   50.9141
# G_LNG                                                   4.37061
# Name: 17179, dtype: object
# ID                        7131414
# POSTAL_CODE                  1800
# BEDROOMS                        4
# LIVING_AREA                   191
# LAND                          135
# PRICE                      335000
# POSTED                  8/25/2017
# VIEWS                         NaN
# SAVES                         NaN
# TYPE                        House
# LOCATION       1800    Vilvoorde
# COMMUNE                 Vilvoorde
# G_LOCATION     Vilvoorde, Belgium
# G_LAT                     50.9273
# G_LNG                     4.42579
# Name: 17181, dtype: object
# ID                                                      7131090
# POSTAL_CODE                                                1800
# BEDROOMS                                                      4
# LIVING_AREA                                                 155
# LAND                                                        159
# PRICE                                                    310000
# POSTED                                                8/25/2017
# VIEWS                                                       NaN
# SAVES                                                       NaN
# TYPE                                                      House
# LOCATION          Quinten  Metsijsstraat  13 1800    Vilvoorde
# COMMUNE                                               Vilvoorde
# G_LOCATION     Quinten Metsysstraat 13, 1800 Vilvoorde, Belgium
# G_LAT                                                   50.9201
# G_LNG                                                    4.4072
# Name: 17182, dtype: object
# ID                                        7128236
# POSTAL_CODE                                  1800
# BEDROOMS                                        3
# LIVING_AREA                                   120
# LAND                                          NaN
# PRICE                                      239000
# POSTED                                  8/23/2017
# VIEWS                                         NaN
# SAVES                                         NaN
# TYPE                                    Apartment
# LOCATION                       1800    Koningslo
# COMMUNE                                 Vilvoorde
# G_LOCATION     Koningslo, 1800 Vilvoorde, Belgium
# G_LAT                                     50.9062
# G_LNG                                     4.37945
# Name: 17183, dtype: object
# ID                        7127707
# POSTAL_CODE                  1800
# BEDROOMS                        4
# LIVING_AREA                   213
# LAND                          860
# PRICE                      389000
# POSTED                  8/23/2017
# VIEWS                         NaN
# SAVES                         NaN
# TYPE                        House
# LOCATION       1800    Vilvoorde
# COMMUNE                 Vilvoorde
# G_LOCATION          1800, Belgium
# G_LAT                     50.9377
# G_LNG                     4.46053
# Name: 17184, dtype: object
# ID                        7125685
# POSTAL_CODE                  1800
# BEDROOMS                        4
# LIVING_AREA                   140
# LAND                          180
# PRICE                      279000
# POSTED                  8/22/2017
# VIEWS                         228
# SAVES                           3
# TYPE                        House
# LOCATION       1800    Vilvoorde
# COMMUNE                 Vilvoorde
# G_LOCATION          1800, Belgium
# G_LAT                     50.9377
# G_LNG                     4.46053
# Name: 17187, dtype: object
# ID                        7121462
# POSTAL_CODE                  1800
# BEDROOMS                        3
# LIVING_AREA                   176
# LAND                          NaN
# PRICE                      239000
# POSTED                  8/18/2017
# VIEWS                         361
# SAVES                           3
# TYPE                    Apartment
# LOCATION       1800    Vilvoorde
# COMMUNE                 Vilvoorde
# G_LOCATION          1800, Belgium
# G_LAT                     50.9377
# G_LNG                     4.46053
# Name: 17190, dtype: object
# ID                                                7121416
# POSTAL_CODE                                          1800
# BEDROOMS                                                3
# LIVING_AREA                                           167
# LAND                                                  255
# PRICE                                              349000
# POSTED                                          8/18/2017
# VIEWS                                                 741
# SAVES                                                  11
# TYPE                                                House
# LOCATION               Callaertstraat  40 1800    Peutie
# COMMUNE                                         Vilvoorde
# G_LOCATION     Callaertstraat 40, 1800 Vilvoorde, Belgium
# G_LAT                                              50.929
# G_LNG                                             4.45551
# Name: 17191, dtype: object
# ID                                                 7119745
# POSTAL_CODE                                           1800
# BEDROOMS                                                 3
# LIVING_AREA                                            108
# LAND                                                    75
# PRICE                                               199900
# POSTED                                           8/17/2017
# VIEWS                                                  NaN
# SAVES                                                  NaN
# TYPE                                                 House
# LOCATION            Steevoortstraat  68 1800    Vilvoorde
# COMMUNE                                          Vilvoorde
# G_LOCATION     Steevoortstraat 68, 1800 Vilvoorde, Belgium
# G_LAT                                              50.9279
# G_LNG                                              4.44714
# Name: 17192, dtype: object
# ID                                                7115364
# POSTAL_CODE                                          1800
# BEDROOMS                                                3
# LIVING_AREA                                            95
# LAND                                                  NaN
# PRICE                                              269000
# POSTED                                          8/14/2017
# VIEWS                                                 NaN
# SAVES                                                 NaN
# TYPE                                            Apartment
# LOCATION       Leuvensesteenweg  10223 1800    Vilvoorde
# COMMUNE                                         Vilvoorde
# G_LOCATION      Leuvensesteenweg, 1800 Vilvoorde, Belgium
# G_LAT                                             50.9268
# G_LNG                                             4.44448
# Name: 17194, dtype: object
# ID                                        7113774
# POSTAL_CODE                                  1800
# BEDROOMS                                        3
# LIVING_AREA                                   131
# LAND                                          187
# PRICE                                      340000
# POSTED                                  8/12/2017
# VIEWS                                         NaN
# SAVES                                         NaN
# TYPE                                        House
# LOCATION            1800    Vilvoorde  Koningslo
# COMMUNE                                 Vilvoorde
# G_LOCATION     Koningslo, 1800 Vilvoorde, Belgium
# G_LAT                                     50.9062
# G_LNG                                     4.37945
# Name: 17195, dtype: object
# ID                                            7113242
# POSTAL_CODE                                      1800
# BEDROOMS                                            3
# LIVING_AREA                                        95
# LAND                                              NaN
# PRICE                                          229000
# POSTED                                      8/12/2017
# VIEWS                                             NaN
# SAVES                                             NaN
# TYPE                                            House
# LOCATION          Indringingsweg   1800    Vilvoorde
# COMMUNE                                     Vilvoorde
# G_LOCATION     Indringingsweg, 1800 Vilvorde, Belgium
# G_LAT                                         50.9072
# G_LNG                                         4.38475
# Name: 17196, dtype: object
# ID                                        7111541
# POSTAL_CODE                                  1800
# BEDROOMS                                        4
# LIVING_AREA                                   165
# LAND                                          213
# PRICE                                      349000
# POSTED                                  8/10/2017
# VIEWS                                         299
# SAVES                                           6
# TYPE                                        House
# LOCATION                       1800    Koningslo
# COMMUNE                                 Vilvoorde
# G_LOCATION     Koningslo, 1800 Vilvoorde, Belgium
# G_LAT                                     50.9062
# G_LNG                                     4.37945
# Name: 17198, dtype: object
# ID                                             7110474
# POSTAL_CODE                                       1800
# BEDROOMS                                             3
# LIVING_AREA                                        120
# LAND                                               160
# PRICE                                           269850
# POSTED                                       8/10/2017
# VIEWS                                              267
# SAVES                                                1
# TYPE                                             House
# LOCATION               Vredestraat  16 1800    Peutie
# COMMUNE                                      Vilvoorde
# G_LOCATION     Vredestraat 16, 1800 Vilvoorde, Belgium
# G_LAT                                          50.9269
# G_LNG                                          4.45712
# Name: 17199, dtype: object
# ID                                               7107331
# POSTAL_CODE                                         1800
# BEDROOMS                                               4
# LIVING_AREA                                          225
# LAND                                                 441
# PRICE                                             437000
# POSTED                                          8/8/2017
# VIEWS                                                NaN
# SAVES                                                NaN
# TYPE                                               House
# LOCATION       De  pomp  27  box1800 1800     Vilvoorde
# COMMUNE                                        Vilvoorde
# G_LOCATION
# G_LAT
# G_LNG
# Name: 17201, dtype: object
# ID                                                     7105470
# POSTAL_CODE                                               1800
# BEDROOMS                                                     3
# LIVING_AREA                                                100
# LAND                                                       NaN
# PRICE                                                   225000
# POSTED                                                8/7/2017
# VIEWS                                                      NaN
# SAVES                                                      NaN
# TYPE                                                     House
# LOCATION       Warandelaan  21B3 1800    Vilvoorde  Koningslo
# COMMUNE                                              Vilvoorde
# G_LOCATION
# G_LAT
# G_LNG
# Name: 17202, dtype: object
# ID                        7105219
# POSTAL_CODE                  1800
# BEDROOMS                        5
# LIVING_AREA                   300
# LAND                          575
# PRICE                      575000
# POSTED                   8/7/2017
# VIEWS                         NaN
# SAVES                         NaN
# TYPE                        House
# LOCATION       1800    Vilvoorde
# COMMUNE                 Vilvoorde
# G_LOCATION          1800, Belgium
# G_LAT                     50.9377
# G_LNG                     4.46053
# Name: 17203, dtype: object
# ID                                                    7105070
# POSTAL_CODE                                              1800
# BEDROOMS                                                    5
# LIVING_AREA                                               205
# LAND                                                      139
# PRICE                                                  369000
# POSTED                                               8/6/2017
# VIEWS                                                      54
# SAVES                                                       1
# TYPE                                                Apartment
# LOCATION       Meeuwenlaan  111 1800    Vilvoorde  Koningslo
# COMMUNE                                             Vilvoorde
# G_LOCATION           Meeuwenlaan 111, 1800 Vilvoorde, Belgium
# G_LAT                                                 50.9114
# G_LNG                                                 4.36714
# Name: 17205, dtype: object
# ID                                                   7103346
# POSTAL_CODE                                             1800
# BEDROOMS                                                   5
# LIVING_AREA                                              208
# LAND                                                     245
# PRICE                                                 399000
# POSTED                                              8/4/2017
# VIEWS                                                    NaN
# SAVES                                                    NaN
# TYPE                                                   House
# LOCATION       Steenstraat  77 1800    Vilvoorde  Koningslo
# COMMUNE                                            Vilvoorde
# G_LOCATION           Steenstraat 77, 1800 Vilvoorde, Belgium
# G_LAT                                                50.9057
# G_LNG                                                4.37628
# Name: 17207, dtype: object
# ID                                        7101636
# POSTAL_CODE                                  1800
# BEDROOMS                                        4
# LIVING_AREA                                   200
# LAND                                          275
# PRICE                                      429000
# POSTED                                   8/3/2017
# VIEWS                                         343
# SAVES                                           3
# TYPE                                        House
# LOCATION            1800    Vilvoorde  Koningslo
# COMMUNE                                 Vilvoorde
# G_LOCATION     Koningslo, 1800 Vilvoorde, Belgium
# G_LAT                                     50.9062
# G_LNG                                     4.37945
# Name: 17208, dtype: object
# ID                                                       7100319
# POSTAL_CODE                                                 1800
# BEDROOMS                                                       4
# LIVING_AREA                                                  220
# LAND                                                         718
# PRICE                                                     432000
# POSTED                                                  8/3/2017
# VIEWS                                                        385
# SAVES                                                         10
# TYPE                                                       House
# LOCATION       Grimbergsesteenweg  228 1800    VilvoordeGrimb...
# COMMUNE                                                Vilvoorde
# G_LOCATION       Grimbergsesteenweg 228, 1800 Vilvoorde, Belgium
# G_LAT                                                    50.9255
# G_LNG                                                     4.4062
# Name: 17209, dtype: object
# ID                                             7098922
# POSTAL_CODE                                       1800
# BEDROOMS                                             3
# LIVING_AREA                                        196
# LAND                                               745
# PRICE                                           387000
# POSTED                                        8/2/2017
# VIEWS                                              620
# SAVES                                               17
# TYPE                                             House
# LOCATION            Grensstraat  19 1800    Vilvoorde
# COMMUNE                                      Vilvoorde
# G_LOCATION     Grensstraat 19, 1800 Vilvoorde, Belgium
# G_LAT                                            50.95
# G_LNG                                          4.48159
# Name: 17210, dtype: object
# ID                                        7098129
# POSTAL_CODE                                  1800
# BEDROOMS                                        3
# LIVING_AREA                                   205
# LAND                                          NaN
# PRICE                                      425000
# POSTED                                   8/1/2017
# VIEWS                                         262
# SAVES                                           0
# TYPE                                        House
# LOCATION                     1800     KONINGSLOO
# COMMUNE                                 Vilvoorde
# G_LOCATION     Koningslo, 1800 Vilvoorde, Belgium
# G_LAT                                     50.9062
# G_LNG                                     4.37945
# Name: 17211, dtype: object
# ID                        7098037
# POSTAL_CODE                  1800
# BEDROOMS                        3
# LIVING_AREA                   130
# LAND                          NaN
# PRICE                      145000
# POSTED                   8/1/2017
# VIEWS                         229
# SAVES                           2
# TYPE                        House
# LOCATION       1800    Vilvoorde
# COMMUNE                 Vilvoorde
# G_LOCATION          1800, Belgium
# G_LAT                     50.9377
# G_LNG                     4.46053
# Name: 17212, dtype: object
# ID                        7097124
# POSTAL_CODE                  1800
# BEDROOMS                        3
# LIVING_AREA                   130
# LAND                          NaN
# PRICE                      269000
# POSTED                   8/1/2017
# VIEWS                         146
# SAVES                           0
# TYPE                    Apartment
# LOCATION       1800    Vilvoorde
# COMMUNE                 Vilvoorde
# G_LOCATION          1800, Belgium
# G_LAT                     50.9377
# G_LNG                     4.46053
# Name: 17213, dtype: object
# ID                        7096666
# POSTAL_CODE                  1800
# BEDROOMS                        4
# LIVING_AREA                   170
# LAND                          420
# PRICE                      389000
# POSTED                  7/31/2017
# VIEWS                         266
# SAVES                           2
# TYPE                        House
# LOCATION       1800    Vilvoorde
# COMMUNE                 Vilvoorde
# G_LOCATION     Vilvoorde, Belgium
# G_LAT                     50.9273
# G_LNG                     4.42579
# Name: 17214, dtype: object
# ID                        7096046
# POSTAL_CODE                  1800
# BEDROOMS                        4
# LIVING_AREA                   200
# LAND                          190
# PRICE                      275000
# POSTED                  7/31/2017
# VIEWS                         786
# SAVES                          10
# TYPE                        House
# LOCATION       1800    Vilvoorde
# COMMUNE                 Vilvoorde
# G_LOCATION     Vilvoorde, Belgium
# G_LAT                     50.9273
# G_LNG                     4.42579
# Name: 17217, dtype: object
# ID                                                7095894
# POSTAL_CODE                                          1800
# BEDROOMS                                                3
# LIVING_AREA                                            95
# LAND                                                  NaN
# PRICE                                              244000
# POSTED                                          7/31/2017
# VIEWS                                                 338
# SAVES                                                   3
# TYPE                                            Apartment
# LOCATION       Leuvensesteenweg  10223 1800    Vilvoorde
# COMMUNE                                         Vilvoorde
# G_LOCATION      Leuvensesteenweg, 1800 Vilvoorde, Belgium
# G_LAT                                             50.9268
# G_LNG                                             4.44448
# Name: 17218, dtype: object
# ID                                               7095873
# POSTAL_CODE                                         1800
# BEDROOMS                                               3
# LIVING_AREA                                          NaN
# LAND                                                 350
# PRICE                                             245000
# POSTED                                         7/31/2017
# VIEWS                                               1280
# SAVES                                                 17
# TYPE                                               House
# LOCATION            Kwakkelstraat  71 1800    Vilvoorde
# COMMUNE                                        Vilvoorde
# G_LOCATION     Kwakkelstraat 71, 1800 Vilvoorde, Belgium
# G_LAT                                            50.9079
# G_LNG                                               4.38
# Name: 17219, dtype: object
# ID                                        7095036
# POSTAL_CODE                                  1800
# BEDROOMS                                        3
# LIVING_AREA                                   196
# LAND                                          276
# PRICE                                      359000
# POSTED                                  7/29/2017
# VIEWS                                        1112
# SAVES                                          13
# TYPE                                        House
# LOCATION           Arendlaan   1800    Vilvoorde
# COMMUNE                                 Vilvoorde
# G_LOCATION     Arendlaan, 1800 Vilvoorde, Belgium
# G_LAT                                     50.9096
# G_LNG                                      4.3672
# Name: 17220, dtype: object
# ID                                                 7093749
# POSTAL_CODE                                           1800
# BEDROOMS                                                 4
# LIVING_AREA                                            140
# LAND                                                   170
# PRICE                                               184000
# POSTED                                           7/28/2017
# VIEWS                                                 1735
# SAVES                                                   19
# TYPE                                                 House
# LOCATION            Tuchthuisstraat  29 1800    Vilvoorde
# COMMUNE                                          Vilvoorde
# G_LOCATION     Tuchthuisstraat 29, 1800 Vilvoorde, Belgium
# G_LAT                                              50.9256
# G_LNG                                              4.42411
# Name: 17223, dtype: object
# ID                                             7089999
# POSTAL_CODE                                       1800
# BEDROOMS                                             5
# LIVING_AREA                                        176
# LAND                                                85
# PRICE                                           299000
# POSTED                                       7/25/2017
# VIEWS                                              453
# SAVES                                                1
# TYPE                                             House
# LOCATION           Koepoortstraat   1800    Vilvoorde
# COMMUNE                                      Vilvoorde
# G_LOCATION     Koepoortstraat, 1800 Vilvoorde, Belgium
# G_LAT                                          50.9249
# G_LNG                                          4.42681
# Name: 17226, dtype: object
# ID                                                    7087380
# POSTAL_CODE                                              1800
# BEDROOMS                                                    3
# LIVING_AREA                                               220
# LAND                                                      300
# PRICE                                                  259000
# POSTED                                              7/23/2017
# VIEWS                                                    1075
# SAVES                                                       5
# TYPE                                                    House
# LOCATION            grimbergsesteenweg  60 1800    Vilvoorde
# COMMUNE                                             Vilvoorde
# G_LOCATION     Grimbergsesteenweg 60, 1800 Vilvoorde, Belgium
# G_LAT                                                 50.9253
# G_LNG                                                 4.41373
# Name: 17227, dtype: object
# ID                                           7085764
# POSTAL_CODE                                     1800
# BEDROOMS                                           3
# LIVING_AREA                                      130
# LAND                                             674
# PRICE                                         375000
# POSTED                                     7/20/2017
# VIEWS                                           1197
# SAVES                                              8
# TYPE                                           House
# LOCATION            Ravenlaan  21 1800    Vilvoorde
# COMMUNE                                    Vilvoorde
# G_LOCATION     Ravenlaan 21, 1800 Vilvoorde, Belgium
# G_LAT                                        50.9106
# G_LNG                                        4.36869
# Name: 17229, dtype: object
# ID                                                       7084180
# POSTAL_CODE                                                 1800
# BEDROOMS                                                       4
# LIVING_AREA                                                  220
# LAND                                                         NaN
# PRICE                                                     317000
# POSTED                                                 7/19/2017
# VIEWS                                                       1403
# SAVES                                                         16
# TYPE                                                       House
# LOCATION       Roger  de  Grimberghestraat  70 1800    Vilvoo...
# COMMUNE                                                Vilvoorde
# G_LOCATION     Roger de Grimberghestraat 70, 1800 Vilvoorde, ...
# G_LAT                                                    50.9301
# G_LNG                                                    4.41874
# Name: 17230, dtype: object
# ID                                             7084061
# POSTAL_CODE                                       1800
# BEDROOMS                                             3
# LIVING_AREA                                        180
# LAND                                               130
# PRICE                                           299000
# POSTED                                       7/19/2017
# VIEWS                                             2436
# SAVES                                               25
# TYPE                                             House
# LOCATION           Papegaaistraat   1800    Vilvoorde
# COMMUNE                                      Vilvoorde
# G_LOCATION     Papegaaistraat, 1800 Vilvoorde, Belgium
# G_LAT                                          50.9162
# G_LNG                                          4.37232
# Name: 17231, dtype: object
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-fcb5a47178e1> in <module>()
#       3     print row
#       4     #print "before="+row["LOCATION"]
# ----> 5     geocode_result = json.dumps(gmaps.geocode(row["LOCATION"]), sort_keys=True, indent=4)
#       6     #print geocode_result
#       7
#
# /Users/gratiel/anaconda/lib/python2.7/site-packages/googlemaps/client.pyc in wrapper(*args, **kwargs)
#     354     def wrapper(*args, **kwargs):
#     355         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 356         result = func(*args, **kwargs)
#     357         try:
#     358             del args[0]._extra_params
#
# /Users/gratiel/anaconda/lib/python2.7/site-packages/googlemaps/geocoding.pyc in geocode(client, address, components, bounds, region, language)
#      66         params["language"] = language
#      67
# ---> 68     return client._request("/maps/api/geocode/json", params)["results"]
#      69
#      70
#
# /Users/gratiel/anaconda/lib/python2.7/site-packages/googlemaps/client.pyc in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     227         try:
#     228             response = requests_method(base_url + authed_url,
# --> 229                                        **final_requests_kwargs)
#     230         except requests.exceptions.Timeout:
#     231             raise googlemaps.exceptions.Timeout()
#
# /Users/gratiel/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in get(self, url, **kwargs)
#     519
#     520         kwargs.setdefault('allow_redirects', True)
# --> 521         return self.request('GET', url, **kwargs)
#     522
#     523     def options(self, url, **kwargs):
#
# /Users/gratiel/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /Users/gratiel/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /Users/gratiel/anaconda/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /Users/gratiel/anaconda/lib/python2.7/site-packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /Users/gratiel/anaconda/lib/python2.7/site-packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378         try:
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
#
# /Users/gratiel/anaconda/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1119
#    1120         try:
# -> 1121             response.begin()
#    1122             assert response.will_close != _UNKNOWN
#    1123             self.__state = _CS_IDLE
#
# /Users/gratiel/anaconda/lib/python2.7/httplib.pyc in begin(self)
#     436         # read until we get a non-100 response
#     437         while True:
# --> 438             version, status, reason = self._read_status()
#     439             if status != CONTINUE:
#     440                 break
#
# /Users/gratiel/anaconda/lib/python2.7/httplib.pyc in _read_status(self)
#     392     def _read_status(self):
#     393         # Initialize with Simple-Response defaults
# --> 394         line = self.fp.readline(_MAXLINE + 1)
#     395         if len(line) > _MAXLINE:
#     396             raise LineTooLong("header line")
#
# /Users/gratiel/anaconda/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# /Users/gratiel/anaconda/lib/python2.7/site-packages/urllib3/contrib/pyopenssl.pyc in recv(self, *args, **kwargs)
#     256     def recv(self, *args, **kwargs):
#     257         try:
# --> 258             data = self.connection.recv(*args, **kwargs)
#     259         except OpenSSL.SSL.SysCallError as e:
#     260             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /Users/gratiel/anaconda/lib/python2.7/site-packages/OpenSSL/SSL.pyc in recv(self, bufsiz, flags)
#    1513             result = _lib.SSL_peek(self._ssl, buf, bufsiz)
#    1514         else:
# -> 1515             result = _lib.SSL_read(self._ssl, buf, bufsiz)
#    1516         self._raise_ssl_error(self._ssl, result)
#    1517         return _ffi.buffer(buf, result)[:]
#
# KeyboardInterrupt:

# %%
test_df

test_df.to_csv(r'/Users/gratiel/Documents/work/house_location/g_sales.txt', header=True, index=None, sep=',', mode='w')
